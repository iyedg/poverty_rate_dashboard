# %%
import json

import folium
import geopandas as gpd
import requests

# %%
geojson_url = "http://www.openculture.gov.tn/dataset/39ee59b8-f5b5-4459-b5fc-a9d31f23c385/resource/0a2d20fb-fca4-4487-b457-3154f67c35e4/download/delegations-full.geojson"
geojson_url = "http://catalog.industrie.gov.tn/dataset/9910662a-4594-453f-a710-b2f339e0d637/resource/70f8c482-abdb-45f2-8f84-bb3f3955c5a3/download/tncirconscriptions.geojson"

# %%
geo_df = (
    gpd.read_file(geojson_url)
)
geo_df
# Out:
#     circo_id    circo_na_1                                           geometry
# 0      111.0       Tunis 1  POLYGON ((10.19070 36.79449, 10.19458 36.79449...
# 1      112.0       Tunis 2  POLYGON ((10.14433 36.81902, 10.14484 36.81630...
# 2      120.0        Ariana  MULTIPOLYGON (((10.23430 36.95047, 10.23649 36...
# 3      130.0     Ben Arous  POLYGON ((10.20188 36.75358, 10.20487 36.75571...
# 4      140.0       Manubah  POLYGON ((10.05623 36.84281, 10.07144 36.83174...
# 5      151.0      Nabeul 1  MULTIPOLYGON (((11.03542 37.08903, 11.03542 37...
# 6      152.0      Nabeul 2  MULTIPOLYGON (((10.77932 36.89399, 10.78177 36...
# 7      160.0      Zaghouan  POLYGON ((10.35088 36.38559, 10.35038 36.38438...
# 8      170.0       Bizerte  MULTIPOLYGON (((9.79180 36.98035, 9.79137 36.9...
# 9      210.0          Béja  POLYGON ((9.08780 37.15875, 9.08878 37.15524, ...
# 10     220.0      Jendouba  POLYGON ((8.93042 36.82695, 8.93002 36.82038, ...
# 11     230.0        Le Kef  POLYGON ((8.61521 35.74853, 8.61645 35.74373, ...
# 12     240.0       Siliana  POLYGON ((9.26936 35.70357, 9.27516 35.69400, ...
# 13     310.0        Sousse  MULTIPOLYGON (((10.21080 35.75941, 10.20651 35...
# 14     320.0      Monastir  MULTIPOLYGON (((10.82903 35.73569, 10.82903 35...
# 15     330.0        Mahdia  MULTIPOLYGON (((11.16431 35.21042, 11.16431 35...
# 16     341.0        Sfax 1  MULTIPOLYGON (((11.08820 34.67403, 11.08820 34...
# 17     342.0        Sfax 2  MULTIPOLYGON (((10.73527 34.78593, 10.75152 34...
# 18     410.0      Kairouan  POLYGON ((9.67631 35.23846, 9.67597 35.23893, ...
# 19     420.0     Kassérine  POLYGON ((8.84028 35.75719, 8.84275 35.75603, ...
# 20     430.0  Sidi Bou Zid  POLYGON ((9.85659 34.60759, 9.85994 34.60263, ...
# 21     510.0         Gabès  POLYGON ((10.17681 33.83070, 10.17681 33.83042...
# 22     520.0      Médenine  MULTIPOLYGON (((10.97375 33.67403, 10.97375 33...
# 23     530.0     Tataouine  POLYGON ((10.60704 33.21414, 10.66889 33.18240...
# 24     610.0         Gafsa  POLYGON ((8.59598 34.09948, 8.56817 34.09837, ...
# 25     620.0        Tozeur  POLYGON ((7.97557 33.53900, 7.94986 33.52157, ...
# 26     630.0        Kebili  POLYGON ((9.54051 33.61094, 9.54187 33.60920, ...

# %%
m = folium.Map(location=[33.8869, 9.5375], zoom_start=6, zoom_control=False,)

# %%
folium.Choropleth(
    geo_data=geojson_url,
    name="choro",
    columns=[],
    key_on="properties.circo_id",
    data=geo_df,
    fill_color="YlGn",
).add_to(m)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-c8583e7652b5> in <module>
#       5     key_on="properties.circo_id",
#       6     data=geo_df,
# ----> 7     fill_color="YlGn",
#       8 ).add_to(m)
#
# ~/.pyenv/versions/3.7.0/lib/python3.7/site-packages/folium/features.py in __init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, **kwargs)
#    1156         if hasattr(data, 'set_index'):
#    1157             # This is a pd.DataFrame
# -> 1158             color_data = data.set_index(columns[0])[columns[1]].to_dict()
#    1159         elif hasattr(data, 'to_dict'):
#    1160             # This is a pd.Series
#
# TypeError: 'NoneType' object is not subscriptable

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
